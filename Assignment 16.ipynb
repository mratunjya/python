# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 from google.colab import files
#       2 uploaded = files.upload()
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
dataset = pd.read_csv("heart.csv")
dataset
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
X = dataset.iloc[0:41, :]
data = pd.DataFrame(X, columns = ['Age', 'RestingBP', 'Cholesterol', 'FastingBS','MaxHR', 'HeartDisease'])
data
# Out:
#     Age  RestingBP  Cholesterol  FastingBS  MaxHR  HeartDisease
# 0    40        140          289          0    172             0
# 1    49        160          180          0    156             1
# 2    37        130          283          0     98             0
# 3    48        138          214          0    108             1
# 4    54        150          195          0    122             0
# 5    39        120          339          0    170             0
# 6    45        130          237          0    170             0
# 7    54        110          208          0    142             0
# 8    37        140          207          0    130             1
# 9    48        120          284          0    120             0
# 10   37        130          211          0    142             0
# 11   58        136          164          0     99             1
# 12   39        120          204          0    145             0
# 13   49        140          234          0    140             1
# 14   42        115          211          0    137             0
# 15   54        120          273          0    150             0
# 16   38        110          196          0    166             1
# 17   43        120          201          0    165             0
# 18   60        100          248          0    125             1
# 19   36        120          267          0    160             1
# 20   43        100          223          0    142             0
# 21   44        120          184          0    142             0
# 22   49        124          201          0    164             0
# 23   44        150          288          0    150             1
# 24   40        130          215          0    138             0
# 25   36        130          209          0    178             0
# 26   53        124          260          0    112             0
# 27   52        120          284          0    118             0
# 28   53        113          468          0    127             0
# 29   51        125          188          0    145             0
# 30   53        145          518          0    130             1
# 31   56        130          167          0    114             0
# 32   54        125          224          0    122             1
# 33   41        130          172          0    130             1
# 34   43        150          186          0    154             0
# 35   32        125          254          0    155             0
# 36   65        140          306          1     87             1
# 37   41        110          250          0    142             0
# 38   48        120          177          1    148             0
# 39   48        150          227          0    130             0
# 40   54        150          230          0    130             0

# %%
#Line Plot
data.plot()

# %%
# Sub Plot
data.plot(subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f32f3f9b710>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f32f3b121d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f32f3acb510>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f32f3a84850>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f32f3a3bb90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f32f39f4ed0>],
#       dtype=object)

# %%
#Plot against two features
data.plot(x='Age', y='RestingBP')

# %%
#Not to be written in file
data.plot(kind='hist')

# %%
data.plot(kind='bar', figsize=(50,10))

# %%
#autopct - auto percentage - decides the angle for the pie plot
data.groupby(['Age']).sum().plot(kind='pie',y='HeartDisease', autopct='%1.0f%%')

# %%
import seaborn as sn
import numpy as np
data = pd.DataFrame(np.random.random((7,7)))
sn.heatmap(data)

# %%
sn.heatmap(data, annot=True, annot_kws={'size':7})

# %%
sn.pairplot(data, hue='HeartDisease')

# %%
axes=plt.gca()
data.plot(kind='line', x='HeartDisease', y='Age', ax=axes);
data.plot(kind='line', x='HeartDisease', y='RestingBP', ax=axes);
data.plot(kind='line', x='HeartDisease', y='Cholesterol', ax=axes);
